# %% [markdown]
# # Pytorch를 활용한 NSMC (네이버 영화평 감정분류) 모델
# ## 모델 : KoELECTRA Model
# 박장원님의 KoELECTRA-Base_v3 모델 사용<br>
#
# ## Dataset
# 네이버 영화 리뷰 데이터셋<br>
#
# ## References
# - https://github.com/monologg/KoELECTRA
# - https://github.com/e9t/nsmc
# - https://huggingface.co/transformers/training.html
# - http://wikidocs.net/book/2155<br>
#   (네이버 영화 감정 분류_데이터 구조 분석 부분 참조)
#
# ## 개발 환경
#   - Google Corab (With GPU)<br>
#   - 구글 드라이브 연동 후 본인 경로 설정 필수<br>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# transformers 설치
# HuggingFace transformers 설치 및 NSMC 데이터셋 다운로드
# !pip install transformers
# !wget https://raw.githubusercontent.com/e9t/nsmc/master/ratings_test.txt
# !wget https://raw.githubusercontent.com/e9t/nsmc/master/ratings_train.txt
# Out:
# Collecting transformers
#   Downloading https://files.pythonhosted.org/packages/50/0c/7d5950fcd80b029be0a8891727ba21e0cd27692c407c51261c3c921f6da3/transformers-4.1.1-py3-none-any.whl (1.5MB)
#      |████████████████████████████████| 1.5MB 12.8MB/s
# Requirement already satisfied: requests in /usr/local/lib/python3.6/dist-packages (from transformers) (2.23.0)
# Requirement already satisfied: filelock in /usr/local/lib/python3.6/dist-packages (from transformers) (3.0.12)
# Collecting sacremoses
#   Downloading https://files.pythonhosted.org/packages/7d/34/09d19aff26edcc8eb2a01bed8e98f13a1537005d31e95233fd48216eed10/sacremoses-0.0.43.tar.gz (883kB)
#      |████████████████████████████████| 890kB 47.0MB/s
# Requirement already satisfied: packaging in /usr/local/lib/python3.6/dist-packages (from transformers) (20.8)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.6/dist-packages (from transformers) (2019.12.20)
# Requirement already satisfied: dataclasses; python_version < "3.7" in /usr/local/lib/python3.6/dist-packages (from transformers) (0.8)
# Requirement already satisfied: numpy in /usr/local/lib/python3.6/dist-packages (from transformers) (1.19.4)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.6/dist-packages (from transformers) (4.41.1)
# Collecting tokenizers==0.9.4
#   Downloading https://files.pythonhosted.org/packages/0f/1c/e789a8b12e28be5bc1ce2156cf87cb522b379be9cadc7ad8091a4cc107c4/tokenizers-0.9.4-cp36-cp36m-manylinux2010_x86_64.whl (2.9MB)
#      |████████████████████████████████| 2.9MB 48.2MB/s
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests->transformers) (3.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests->transformers) (2020.12.5)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests->transformers) (1.24.3)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests->transformers) (2.10)
# Requirement already satisfied: six in /usr/local/lib/python3.6/dist-packages (from sacremoses->transformers) (1.15.0)
# Requirement already satisfied: click in /usr/local/lib/python3.6/dist-packages (from sacremoses->transformers) (7.1.2)
# Requirement already satisfied: joblib in /usr/local/lib/python3.6/dist-packages (from sacremoses->transformers) (1.0.0)
# Requirement already satisfied: pyparsing>=2.0.2 in /usr/local/lib/python3.6/dist-packages (from packaging->transformers) (2.4.7)
# Building wheels for collected packages: sacremoses
#   Building wheel for sacremoses (setup.py) ... done
#   Created wheel for sacremoses: filename=sacremoses-0.0.43-cp36-none-any.whl size=893261 sha256=0a47b644bc1151d111528deee78a20bb62f85f0f489d880352578746fa20dec3
#   Stored in directory: /root/.cache/pip/wheels/29/3c/fd/7ce5c3f0666dab31a50123635e6fb5e19ceb42ce38d4e58f45
# Successfully built sacremoses
# Installing collected packages: sacremoses, tokenizers, transformers
# Successfully installed sacremoses-0.0.43 tokenizers-0.9.4 transformers-4.1.1
# --2020-12-23 02:52:18--  https://raw.githubusercontent.com/e9t/nsmc/master/ratings_test.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 4893335 (4.7M) [text/plain]
# Saving to: ‘ratings_test.txt’
#
# ratings_test.txt    100%[===================>]   4.67M  --.-KB/s    in 0.1s
#
# 2020-12-23 02:52:19 (33.8 MB/s) - ‘ratings_test.txt’ saved [4893335/4893335]
#
# --2020-12-23 02:52:19--  https://raw.githubusercontent.com/e9t/nsmc/master/ratings_train.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 151.101.0.133, 151.101.64.133, 151.101.128.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|151.101.0.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 14628807 (14M) [text/plain]
# Saving to: ‘ratings_train.txt’
#
# ratings_train.txt   100%[===================>]  13.95M  --.-KB/s    in 0.1s
#
# 2020-12-23 02:52:20 (112 MB/s) - ‘ratings_train.txt’ saved [14628807/14628807]

# %%
# 모델에 필요한 도구 불러오기

import pandas as pd
import torch
from torch.nn import functional as F
from torch.utils.data import DataLoader, Dataset
from transformers import AutoTokenizer, ElectraForSequenceClassification, AdamW
from tqdm.notebook import tqdm

# %%
# GPU 활성화

device = torch.device("cuda")

# %%
device
# Out:
# device(type='cuda')

# %% [markdown]
# # Create Model

# %%
# Koelectra 모델 사용 ( 버젼은 Base v1,v2,v3 / small v1, v2, v3 선택 가능)
# 가장 높은 성능을 보여주는 Base v3 버젼으로 Fine Tuing 진행

model = ElectraForSequenceClassification.from_pretrained("monologg/koelectra-base-v3-discriminator").to(device)
# Out:
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=467.0, style=ProgressStyle(description_…
# HBox(children=(FloatProgress(value=0.0, description='Downloading', max=451776329.0, style=ProgressStyle(descri…
# Some weights of the model checkpoint at monologg/koelectra-base-v3-discriminator were not used when initializing ElectraForSequenceClassification: ['discriminator_predictions.dense.weight', 'discriminator_predictions.dense.bias', 'discriminator_predictions.dense_prediction.weight', 'discriminator_predictions.dense_prediction.bias']
# - This IS expected if you are initializing ElectraForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing ElectraForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# Some weights of ElectraForSequenceClassification were not initialized from the model checkpoint at monologg/koelectra-base-v3-discriminator and are newly initialized: ['classifier.dense.weight', 'classifier.dense.bias', 'classifier.out_proj.weight', 'classifier.out_proj.bias']
# You should probably TRAIN this model on a down-stream task to be able to use it for predictions and inference.

# %%
# 이미 학습된 모델 로딩하여 사용할 경우  

#model.load_state_dict(torch.load("Model_Koelectra_best.pt"))

# %% [markdown]
#  # Train & Test Model
#  ## Train Model

# %%
# 데이터 전처리 
# max_lenth 설정 값 : 50 (리뷰 데이터의 max lenth 4사분위 값 : 39)

class NSMCDataset(Dataset):
  
  def __init__(self, csv_file):
    # 일부 값중에 NaN이 있음...
    self.dataset = pd.read_csv(csv_file, sep="\t").dropna(axis=0) 
    # 중복제거
    self.dataset.drop_duplicates(subset=['document'], inplace=True)
    self.tokenizer = AutoTokenizer.from_pretrained("monologg/koelectra-base-v3-discriminator")

    print(self.dataset.describe())
  
  def __len__(self):
    return len(self.dataset)
  def __getitem__(self, idx):
    row = self.dataset.iloc[idx, 1:3].values
    text = row[0]
    y = row[1]

    inputs = self.tokenizer(
        text, 
        return_tensors='pt',
        truncation=True,
        max_length=50,
        pad_to_max_length=True,
        add_special_tokens=True
        )
    
    input_ids = inputs['input_ids'][0]
    attention_mask = inputs['attention_mask'][0]

    return input_ids, attention_mask, y

# %%
# 데이터 로드

train_dataset = NSMCDataset("ratings_train.txt")
test_dataset = NSMCDataset("ratings_test.txt")
# Out:
#                  id          label
# count  1.461820e+05  146182.000000
# mean   6.779186e+06       0.498283
# std    2.919223e+06       0.499999
# min    3.300000e+01       0.000000
# 25%    4.814832e+06       0.000000
# 50%    7.581160e+06       0.000000
# 75%    9.274760e+06       1.000000
# max    1.027815e+07       1.000000
#                  id         label
# count  4.915700e+04  49157.000000
# mean   6.752945e+06      0.502695
# std    2.937158e+06      0.499998
# min    6.010000e+02      0.000000
# 25%    4.777143e+06      0.000000
# 50%    7.565415e+06      1.000000
# 75%    9.260204e+06      1.000000
# max    1.027809e+07      1.000000

# %%
# 에포크, 배치 사이즈 지정, 데이터 로딩

epochs = 10
batch_size = 32

# %%
optimizer = AdamW(model.parameters(), lr=1e-5)
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
test_loader = DataLoader(test_dataset, batch_size=16, shuffle=True)

# %%
# Koelectra Pretrained 모델을 활용한 FineTuing 진행


losses = []
accuracies = []

for i in range(epochs):
    total_loss = 0.0
    correct = 0
    total = 0
    batches = 0
    
    model.train()
    
    for input_ids_batch, attention_masks_batch, y_batch in tqdm(train_loader):
        optimizer.zero_grad()
        y_batch = y_batch.to(device)
        y_pred = model(input_ids_batch.to(device), attention_mask=attention_masks_batch.to(device))[0]
        loss = F.cross_entropy(y_pred, y_batch)
        loss.backward()
        optimizer.step()
        
        total_loss += loss.item()
        
        _, predicted = torch.max(y_pred, 1)
        correct += (predicted == y_batch).sum()
        total += len(y_batch)
        
        batches += 1
        if batches % 100 == 0:
            print("Batch Loss:", total_loss, "Accuracy:", correct.float() / total)
            
    losses.append(total_loss)
    accuracies.append(correct.float() / total)
    print("Train Loss:", total_loss, "Accuracy:", correct.float() / total)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=4569.0), HTML(value='')))
# /usr/local/lib/python3.6/dist-packages/transformers/tokenization_utils_base.py:2179: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   FutureWarning,
# Batch Loss: 62.73163840174675 Accuracy: tensor(0.6606, device='cuda:0')
# Batch Loss: 105.91244420409203 Accuracy: tensor(0.7387, device='cuda:0')
# Batch Loss: 144.55546715855598 Accuracy: tensor(0.7705, device='cuda:0')
# Batch Loss: 179.57454903423786 Accuracy: tensor(0.7914, device='cuda:0')
# Batch Loss: 213.40570282936096 Accuracy: tensor(0.8046, device='cuda:0')
# Batch Loss: 246.81623975932598 Accuracy: tensor(0.8134, device='cuda:0')
# Batch Loss: 276.82369113713503 Accuracy: tensor(0.8227, device='cuda:0')
# Batch Loss: 308.29071935266256 Accuracy: tensor(0.8283, device='cuda:0')
# Batch Loss: 338.63488905876875 Accuracy: tensor(0.8328, device='cuda:0')
# Batch Loss: 369.33980245143175 Accuracy: tensor(0.8369, device='cuda:0')
# Batch Loss: 398.18591302633286 Accuracy: tensor(0.8411, device='cuda:0')
# Batch Loss: 427.2271222025156 Accuracy: tensor(0.8440, device='cuda:0')
# Batch Loss: 456.4415602013469 Accuracy: tensor(0.8468, device='cuda:0')
# Batch Loss: 485.7223693802953 Accuracy: tensor(0.8490, device='cuda:0')
# Batch Loss: 513.08382999897 Accuracy: tensor(0.8514, device='cuda:0')
# Batch Loss: 542.1353479996324 Accuracy: tensor(0.8532, device='cuda:0')
# Batch Loss: 570.2788595445454 Accuracy: tensor(0.8551, device='cuda:0')
# Batch Loss: 597.3219428546727 Accuracy: tensor(0.8569, device='cuda:0')
# Batch Loss: 626.5502614937723 Accuracy: tensor(0.8583, device='cuda:0')
# Batch Loss: 654.264012593776 Accuracy: tensor(0.8598, device='cuda:0')
# Batch Loss: 682.5983945392072 Accuracy: tensor(0.8608, device='cuda:0')
# Batch Loss: 709.5036195777357 Accuracy: tensor(0.8619, device='cuda:0')
# Batch Loss: 735.0477969609201 Accuracy: tensor(0.8633, device='cuda:0')
# Batch Loss: 761.9348037578166 Accuracy: tensor(0.8642, device='cuda:0')
# Batch Loss: 786.6957470029593 Accuracy: tensor(0.8655, device='cuda:0')
# Batch Loss: 811.9170956537127 Accuracy: tensor(0.8663, device='cuda:0')
# Batch Loss: 839.3273044750094 Accuracy: tensor(0.8670, device='cuda:0')
# Batch Loss: 866.5658710077405 Accuracy: tensor(0.8676, device='cuda:0')
# Batch Loss: 893.8746810480952 Accuracy: tensor(0.8682, device='cuda:0')
# Batch Loss: 920.6110236272216 Accuracy: tensor(0.8691, device='cuda:0')
# Batch Loss: 945.447317995131 Accuracy: tensor(0.8698, device='cuda:0')
# Batch Loss: 970.6060837060213 Accuracy: tensor(0.8707, device='cuda:0')
# Batch Loss: 996.431450791657 Accuracy: tensor(0.8715, device='cuda:0')
# Batch Loss: 1021.5391711592674 Accuracy: tensor(0.8722, device='cuda:0')
# Batch Loss: 1047.8827658519149 Accuracy: tensor(0.8727, device='cuda:0')
# Batch Loss: 1072.9342719763517 Accuracy: tensor(0.8732, device='cuda:0')
# Batch Loss: 1099.6987083479762 Accuracy: tensor(0.8737, device='cuda:0')
# Batch Loss: 1128.3633828014135 Accuracy: tensor(0.8737, device='cuda:0')
# Batch Loss: 1153.6238225772977 Accuracy: tensor(0.8742, device='cuda:0')
# Batch Loss: 1179.1251507885754 Accuracy: tensor(0.8747, device='cuda:0')
# Batch Loss: 1204.7948923967779 Accuracy: tensor(0.8753, device='cuda:0')
# Batch Loss: 1230.3462864421308 Accuracy: tensor(0.8757, device='cuda:0')
# Batch Loss: 1256.3267655335367 Accuracy: tensor(0.8761, device='cuda:0')
# Batch Loss: 1283.1049690879881 Accuracy: tensor(0.8763, device='cuda:0')
# Batch Loss: 1306.7006325088441 Accuracy: tensor(0.8768, device='cuda:0')
#
# Train Loss: 1322.8536492418498 Accuracy: tensor(0.8772, device='cuda:0')
# HBox(children=(FloatProgress(value=0.0, max=4569.0), HTML(value='')))
# Batch Loss: 22.15813960507512 Accuracy: tensor(0.9131, device='cuda:0')
# Batch Loss: 44.72907118871808 Accuracy: tensor(0.9094, device='cuda:0')
# Batch Loss: 65.28231054916978 Accuracy: tensor(0.9141, device='cuda:0')
# Batch Loss: 87.64911895245314 Accuracy: tensor(0.9124, device='cuda:0')
# Batch Loss: 107.98705001920462 Accuracy: tensor(0.9144, device='cuda:0')
# Batch Loss: 130.37351258844137 Accuracy: tensor(0.9135, device='cuda:0')
# Batch Loss: 152.91196160018444 Accuracy: tensor(0.9128, device='cuda:0')
# Batch Loss: 173.73727064579725 Accuracy: tensor(0.9126, device='cuda:0')
# Batch Loss: 194.60142933949828 Accuracy: tensor(0.9136, device='cuda:0')
# Batch Loss: 216.05579977110028 Accuracy: tensor(0.9137, device='cuda:0')
# Batch Loss: 237.08345606178045 Accuracy: tensor(0.9136, device='cuda:0')
# Batch Loss: 258.4794291295111 Accuracy: tensor(0.9135, device='cuda:0')
# Batch Loss: 279.7015526033938 Accuracy: tensor(0.9135, device='cuda:0')
# Batch Loss: 300.08271216228604 Accuracy: tensor(0.9141, device='cuda:0')
# Batch Loss: 323.44903987646103 Accuracy: tensor(0.9131, device='cuda:0')
# Batch Loss: 346.3752468302846 Accuracy: tensor(0.9127, device='cuda:0')
# Batch Loss: 366.47489538788795 Accuracy: tensor(0.9128, device='cuda:0')
# Batch Loss: 388.3813543692231 Accuracy: tensor(0.9131, device='cuda:0')
# Batch Loss: 409.0466069765389 Accuracy: tensor(0.9134, device='cuda:0')
# Batch Loss: 429.952185228467 Accuracy: tensor(0.9136, device='cuda:0')
# Batch Loss: 450.7181833386421 Accuracy: tensor(0.9139, device='cuda:0')
# Batch Loss: 472.4291628859937 Accuracy: tensor(0.9136, device='cuda:0')
# Batch Loss: 493.0142462812364 Accuracy: tensor(0.9137, device='cuda:0')
# Batch Loss: 514.6070041842759 Accuracy: tensor(0.9134, device='cuda:0')
# Batch Loss: 535.9524359740317 Accuracy: tensor(0.9134, device='cuda:0')
# Batch Loss: 555.4472406692803 Accuracy: tensor(0.9137, device='cuda:0')
# Batch Loss: 575.6866271607578 Accuracy: tensor(0.9140, device='cuda:0')
# Batch Loss: 597.5866446010768 Accuracy: tensor(0.9139, device='cuda:0')
# Batch Loss: 619.5481226816773 Accuracy: tensor(0.9138, device='cuda:0')
# Batch Loss: 640.0117381587625 Accuracy: tensor(0.9138, device='cuda:0')
# Batch Loss: 660.5130085349083 Accuracy: tensor(0.9141, device='cuda:0')
# Batch Loss: 682.2840948440135 Accuracy: tensor(0.9140, device='cuda:0')
# Batch Loss: 702.0057156682014 Accuracy: tensor(0.9144, device='cuda:0')
# Batch Loss: 725.3940018191934 Accuracy: tensor(0.9142, device='cuda:0')
# Batch Loss: 747.0251925513148 Accuracy: tensor(0.9140, device='cuda:0')
# Batch Loss: 768.3094815313816 Accuracy: tensor(0.9140, device='cuda:0')
# Batch Loss: 791.4481318742037 Accuracy: tensor(0.9138, device='cuda:0')
# Batch Loss: 815.202592022717 Accuracy: tensor(0.9135, device='cuda:0')
# Batch Loss: 837.0861963778734 Accuracy: tensor(0.9136, device='cuda:0')
# Batch Loss: 858.4950812757015 Accuracy: tensor(0.9136, device='cuda:0')
# Batch Loss: 879.7414667662233 Accuracy: tensor(0.9136, device='cuda:0')
# Batch Loss: 900.090590139851 Accuracy: tensor(0.9136, device='cuda:0')
# Batch Loss: 920.4973993357271 Accuracy: tensor(0.9138, device='cuda:0')
# Batch Loss: 941.8366563674062 Accuracy: tensor(0.9138, device='cuda:0')
# Batch Loss: 963.6859819609672 Accuracy: tensor(0.9137, device='cuda:0')
#
# Train Loss: 978.0860839579254 Accuracy: tensor(0.9136, device='cuda:0')
# HBox(children=(FloatProgress(value=0.0, max=4569.0), HTML(value='')))
# Batch Loss: 17.63128402084112 Accuracy: tensor(0.9319, device='cuda:0')
# Batch Loss: 32.71217812784016 Accuracy: tensor(0.9361, device='cuda:0')
# Batch Loss: 48.568199813365936 Accuracy: tensor(0.9365, device='cuda:0')
# Batch Loss: 66.43732070550323 Accuracy: tensor(0.9343, device='cuda:0')
# Batch Loss: 82.94661639630795 Accuracy: tensor(0.9347, device='cuda:0')
# Batch Loss: 100.54162541218102 Accuracy: tensor(0.9341, device='cuda:0')
# Batch Loss: 118.48715105466545 Accuracy: tensor(0.9326, device='cuda:0')
# Batch Loss: 135.5893504936248 Accuracy: tensor(0.9328, device='cuda:0')
# Batch Loss: 153.09669094718993 Accuracy: tensor(0.9329, device='cuda:0')
# Batch Loss: 168.7009390052408 Accuracy: tensor(0.9336, device='cuda:0')
# Batch Loss: 185.91155620478094 Accuracy: tensor(0.9334, device='cuda:0')
# Batch Loss: 202.42324439622462 Accuracy: tensor(0.9335, device='cuda:0')
# Batch Loss: 219.16120314970613 Accuracy: tensor(0.9334, device='cuda:0')
# Batch Loss: 236.7361847665161 Accuracy: tensor(0.9334, device='cuda:0')
# Batch Loss: 254.18213396891952 Accuracy: tensor(0.9333, device='cuda:0')
# Batch Loss: 271.5734090656042 Accuracy: tensor(0.9331, device='cuda:0')
# Batch Loss: 287.3002317883074 Accuracy: tensor(0.9334, device='cuda:0')
# Batch Loss: 303.6707153618336 Accuracy: tensor(0.9336, device='cuda:0')
# Batch Loss: 319.6557606719434 Accuracy: tensor(0.9337, device='cuda:0')
# Batch Loss: 336.4824866335839 Accuracy: tensor(0.9337, device='cuda:0')
# Batch Loss: 352.4277041628957 Accuracy: tensor(0.9338, device='cuda:0')
# Batch Loss: 368.10721083916724 Accuracy: tensor(0.9341, device='cuda:0')
# Batch Loss: 384.9079751316458 Accuracy: tensor(0.9341, device='cuda:0')
# Batch Loss: 401.3285611551255 Accuracy: tensor(0.9343, device='cuda:0')
# Batch Loss: 419.0752256978303 Accuracy: tensor(0.9343, device='cuda:0')
# Batch Loss: 435.9340471941978 Accuracy: tensor(0.9342, device='cuda:0')
# Batch Loss: 452.1931500993669 Accuracy: tensor(0.9343, device='cuda:0')
# Batch Loss: 469.08620211854577 Accuracy: tensor(0.9342, device='cuda:0')
# Batch Loss: 487.5598019734025 Accuracy: tensor(0.9341, device='cuda:0')
# Batch Loss: 506.0088945776224 Accuracy: tensor(0.9339, device='cuda:0')
# Batch Loss: 522.7145009879023 Accuracy: tensor(0.9339, device='cuda:0')
# Batch Loss: 539.1888527069241 Accuracy: tensor(0.9340, device='cuda:0')
# Batch Loss: 557.3889235146344 Accuracy: tensor(0.9340, device='cuda:0')
# Batch Loss: 574.9835701324046 Accuracy: tensor(0.9339, device='cuda:0')
# Batch Loss: 594.7814398519695 Accuracy: tensor(0.9336, device='cuda:0')
# Batch Loss: 611.1873258911073 Accuracy: tensor(0.9338, device='cuda:0')
# Batch Loss: 627.7974248863757 Accuracy: tensor(0.9338, device='cuda:0')
# Batch Loss: 645.2901575863361 Accuracy: tensor(0.9338, device='cuda:0')
# Batch Loss: 662.9579544216394 Accuracy: tensor(0.9337, device='cuda:0')
# Batch Loss: 680.5820005498827 Accuracy: tensor(0.9337, device='cuda:0')
# Batch Loss: 698.100523609668 Accuracy: tensor(0.9337, device='cuda:0')
# Batch Loss: 716.5153274033219 Accuracy: tensor(0.9335, device='cuda:0')
# Batch Loss: 733.7592043895274 Accuracy: tensor(0.9336, device='cuda:0')
# Batch Loss: 751.0292878281325 Accuracy: tensor(0.9336, device='cuda:0')
# Batch Loss: 768.8912749383599 Accuracy: tensor(0.9336, device='cuda:0')
#
# Train Loss: 780.4395019989461 Accuracy: tensor(0.9335, device='cuda:0')
# HBox(children=(FloatProgress(value=0.0, max=4569.0), HTML(value='')))
# Batch Loss: 13.649410327896476 Accuracy: tensor(0.9456, device='cuda:0')
# Batch Loss: 27.590480456128716 Accuracy: tensor(0.9481, device='cuda:0')
# Batch Loss: 40.71216771192849 Accuracy: tensor(0.9503, device='cuda:0')
# Batch Loss: 53.25161198154092 Accuracy: tensor(0.9503, device='cuda:0')
# Batch Loss: 65.74472517520189 Accuracy: tensor(0.9512, device='cuda:0')
# Batch Loss: 78.59244196582586 Accuracy: tensor(0.9509, device='cuda:0')
# Batch Loss: 91.25121049210429 Accuracy: tensor(0.9510, device='cuda:0')
# Batch Loss: 103.50347073469311 Accuracy: tensor(0.9513, device='cuda:0')
# Batch Loss: 115.90388065110892 Accuracy: tensor(0.9516, device='cuda:0')
# Batch Loss: 127.4306680643931 Accuracy: tensor(0.9523, device='cuda:0')
# Batch Loss: 140.58331042993814 Accuracy: tensor(0.9522, device='cuda:0')
# Batch Loss: 154.0808255681768 Accuracy: tensor(0.9522, device='cuda:0')
# Batch Loss: 165.63998152129352 Accuracy: tensor(0.9526, device='cuda:0')
# Batch Loss: 178.54051530361176 Accuracy: tensor(0.9529, device='cuda:0')
# Batch Loss: 191.821366825141 Accuracy: tensor(0.9527, device='cuda:0')
# Batch Loss: 205.85739422310144 Accuracy: tensor(0.9525, device='cuda:0')
# Batch Loss: 217.62172530498356 Accuracy: tensor(0.9526, device='cuda:0')
# Batch Loss: 231.22287583258003 Accuracy: tensor(0.9524, device='cuda:0')
# Batch Loss: 244.586571498774 Accuracy: tensor(0.9524, device='cuda:0')
# Batch Loss: 257.4073215601966 Accuracy: tensor(0.9522, device='cuda:0')
# Batch Loss: 270.45607803110033 Accuracy: tensor(0.9520, device='cuda:0')
# Batch Loss: 283.9538361681625 Accuracy: tensor(0.9520, device='cuda:0')
# Batch Loss: 298.0197659647092 Accuracy: tensor(0.9519, device='cuda:0')
# Batch Loss: 311.19563845638186 Accuracy: tensor(0.9518, device='cuda:0')
# Batch Loss: 325.1176703805104 Accuracy: tensor(0.9517, device='cuda:0')
# Batch Loss: 337.99912214651704 Accuracy: tensor(0.9517, device='cuda:0')
# Batch Loss: 351.47978707868606 Accuracy: tensor(0.9515, device='cuda:0')
# Batch Loss: 366.0984802460298 Accuracy: tensor(0.9514, device='cuda:0')
# Batch Loss: 378.6524643385783 Accuracy: tensor(0.9515, device='cuda:0')
# Batch Loss: 391.6060905708 Accuracy: tensor(0.9516, device='cuda:0')
# Batch Loss: 404.54874128103256 Accuracy: tensor(0.9515, device='cuda:0')
# Batch Loss: 417.981676206924 Accuracy: tensor(0.9514, device='cuda:0')
# Batch Loss: 431.5462582046166 Accuracy: tensor(0.9513, device='cuda:0')
# Batch Loss: 445.07751262094826 Accuracy: tensor(0.9513, device='cuda:0')
# Batch Loss: 456.76111314538866 Accuracy: tensor(0.9515, device='cuda:0')
# Batch Loss: 468.52990939468145 Accuracy: tensor(0.9517, device='cuda:0')
# Batch Loss: 482.06342925690114 Accuracy: tensor(0.9516, device='cuda:0')
# Batch Loss: 497.06293883547187 Accuracy: tensor(0.9515, device='cuda:0')
# Batch Loss: 509.8866051789373 Accuracy: tensor(0.9516, device='cuda:0')
# Batch Loss: 522.4555625515059 Accuracy: tensor(0.9517, device='cuda:0')
# Batch Loss: 535.8115296903998 Accuracy: tensor(0.9515, device='cuda:0')
# Batch Loss: 549.5289163440466 Accuracy: tensor(0.9513, device='cuda:0')
# Batch Loss: 563.0453940769657 Accuracy: tensor(0.9513, device='cuda:0')
# Batch Loss: 575.1711885174736 Accuracy: tensor(0.9513, device='cuda:0')
# Batch Loss: 588.5172492433339 Accuracy: tensor(0.9512, device='cuda:0')
#
# Train Loss: 597.8655356639065 Accuracy: tensor(0.9511, device='cuda:0')
# HBox(children=(FloatProgress(value=0.0, max=4569.0), HTML(value='')))
# Batch Loss: 8.323501089587808 Accuracy: tensor(0.9694, device='cuda:0')
# Batch Loss: 17.0713668782264 Accuracy: tensor(0.9691, device='cuda:0')
# Batch Loss: 26.592751291580498 Accuracy: tensor(0.9684, device='cuda:0')
# Batch Loss: 34.94113484118134 Accuracy: tensor(0.9687, device='cuda:0')
# Batch Loss: 44.9347508251667 Accuracy: tensor(0.9681, device='cuda:0')
# Batch Loss: 55.677224828861654 Accuracy: tensor(0.9682, device='cuda:0')
# Batch Loss: 65.16070818621665 Accuracy: tensor(0.9675, device='cuda:0')
# Batch Loss: 75.23286628443748 Accuracy: tensor(0.9669, device='cuda:0')
# Batch Loss: 84.53625689586625 Accuracy: tensor(0.9666, device='cuda:0')
# Batch Loss: 92.6521787950769 Accuracy: tensor(0.9667, device='cuda:0')
# Batch Loss: 103.12879677303135 Accuracy: tensor(0.9663, device='cuda:0')
# Batch Loss: 112.28355337679386 Accuracy: tensor(0.9664, device='cuda:0')
# Batch Loss: 122.7526526376605 Accuracy: tensor(0.9660, device='cuda:0')
# Batch Loss: 133.04902416467667 Accuracy: tensor(0.9658, device='cuda:0')
# Batch Loss: 142.70571441855282 Accuracy: tensor(0.9657, device='cuda:0')
# Batch Loss: 152.47471070475876 Accuracy: tensor(0.9657, device='cuda:0')
# Batch Loss: 163.82869208045304 Accuracy: tensor(0.9653, device='cuda:0')
# Batch Loss: 173.58957661688328 Accuracy: tensor(0.9654, device='cuda:0')
# Batch Loss: 185.0093235913664 Accuracy: tensor(0.9651, device='cuda:0')
# Batch Loss: 194.58474817778915 Accuracy: tensor(0.9651, device='cuda:0')
# Batch Loss: 204.38252783101052 Accuracy: tensor(0.9650, device='cuda:0')
# Batch Loss: 213.4453207794577 Accuracy: tensor(0.9651, device='cuda:0')
# Batch Loss: 224.2043556915596 Accuracy: tensor(0.9648, device='cuda:0')
# Batch Loss: 234.64189872238785 Accuracy: tensor(0.9648, device='cuda:0')
# Batch Loss: 243.6694440562278 Accuracy: tensor(0.9649, device='cuda:0')
# Batch Loss: 253.55925249494612 Accuracy: tensor(0.9649, device='cuda:0')
# Batch Loss: 264.43046359717846 Accuracy: tensor(0.9647, device='cuda:0')
# Batch Loss: 275.7922003492713 Accuracy: tensor(0.9646, device='cuda:0')
# Batch Loss: 285.0401159408502 Accuracy: tensor(0.9647, device='cuda:0')
# Batch Loss: 295.3103657485917 Accuracy: tensor(0.9647, device='cuda:0')
# Batch Loss: 305.13940254971385 Accuracy: tensor(0.9647, device='cuda:0')
# Batch Loss: 316.50632156059146 Accuracy: tensor(0.9646, device='cuda:0')
# Batch Loss: 327.46564256679267 Accuracy: tensor(0.9643, device='cuda:0')
# Batch Loss: 338.06213683169335 Accuracy: tensor(0.9642, device='cuda:0')
# Batch Loss: 347.7628416577354 Accuracy: tensor(0.9642, device='cuda:0')
# Batch Loss: 359.92350363964215 Accuracy: tensor(0.9640, device='cuda:0')
# Batch Loss: 370.2729612304829 Accuracy: tensor(0.9640, device='cuda:0')
# Batch Loss: 380.4384806160815 Accuracy: tensor(0.9640, device='cuda:0')
# Batch Loss: 391.1339767216705 Accuracy: tensor(0.9639, device='cuda:0')
# Batch Loss: 401.78033889457583 Accuracy: tensor(0.9638, device='cuda:0')
# Batch Loss: 412.93863678956404 Accuracy: tensor(0.9637, device='cuda:0')
# Batch Loss: 423.0304506518878 Accuracy: tensor(0.9637, device='cuda:0')
# Batch Loss: 432.88339180639014 Accuracy: tensor(0.9637, device='cuda:0')
# Batch Loss: 443.9850299251266 Accuracy: tensor(0.9635, device='cuda:0')
# Batch Loss: 453.8179793129675 Accuracy: tensor(0.9634, device='cuda:0')
#
# Train Loss: 461.94001254672185 Accuracy: tensor(0.9633, device='cuda:0')
# HBox(children=(FloatProgress(value=0.0, max=4569.0), HTML(value='')))
# Batch Loss: 7.129111479967833 Accuracy: tensor(0.9759, device='cuda:0')
# Batch Loss: 14.80698188720271 Accuracy: tensor(0.9756, device='cuda:0')
# Batch Loss: 23.071983441710472 Accuracy: tensor(0.9740, device='cuda:0')
# Batch Loss: 31.040570307523012 Accuracy: tensor(0.9732, device='cuda:0')
# Batch Loss: 36.77451893314719 Accuracy: tensor(0.9743, device='cuda:0')
# Batch Loss: 43.335151966661215 Accuracy: tensor(0.9751, device='cuda:0')
# Batch Loss: 50.63360673002899 Accuracy: tensor(0.9748, device='cuda:0')
# Batch Loss: 58.44991235015914 Accuracy: tensor(0.9746, device='cuda:0')
# Batch Loss: 65.8245402853936 Accuracy: tensor(0.9744, device='cuda:0')
# Batch Loss: 73.81205550022423 Accuracy: tensor(0.9744, device='cuda:0')
# Batch Loss: 83.06507203169167 Accuracy: tensor(0.9737, device='cuda:0')
# Batch Loss: 88.85276421578601 Accuracy: tensor(0.9743, device='cuda:0')
# Batch Loss: 96.5630983018782 Accuracy: tensor(0.9739, device='cuda:0')
# Batch Loss: 105.18697575177066 Accuracy: tensor(0.9735, device='cuda:0')
# Batch Loss: 111.04222548147663 Accuracy: tensor(0.9740, device='cuda:0')
# Batch Loss: 118.92760141985491 Accuracy: tensor(0.9739, device='cuda:0')
# Batch Loss: 126.90530284168199 Accuracy: tensor(0.9739, device='cuda:0')
# Batch Loss: 135.10144969634712 Accuracy: tensor(0.9736, device='cuda:0')
# Batch Loss: 142.34548387373798 Accuracy: tensor(0.9737, device='cuda:0')
# Batch Loss: 150.28257171122823 Accuracy: tensor(0.9737, device='cuda:0')
# Batch Loss: 157.7147068270715 Accuracy: tensor(0.9738, device='cuda:0')
# Batch Loss: 164.73910688527394 Accuracy: tensor(0.9738, device='cuda:0')
# Batch Loss: 173.3918101961026 Accuracy: tensor(0.9737, device='cuda:0')
# Batch Loss: 181.4216428656364 Accuracy: tensor(0.9736, device='cuda:0')
# Batch Loss: 190.39057379739825 Accuracy: tensor(0.9734, device='cuda:0')
# Batch Loss: 198.89533421827946 Accuracy: tensor(0.9732, device='cuda:0')
# Batch Loss: 206.08963935927022 Accuracy: tensor(0.9732, device='cuda:0')
# Batch Loss: 214.0523041213164 Accuracy: tensor(0.9731, device='cuda:0')
# Batch Loss: 222.85725848155562 Accuracy: tensor(0.9730, device='cuda:0')
# Batch Loss: 231.24288913293276 Accuracy: tensor(0.9729, device='cuda:0')
# Batch Loss: 239.7845011629397 Accuracy: tensor(0.9729, device='cuda:0')
# Batch Loss: 247.10820748016704 Accuracy: tensor(0.9729, device='cuda:0')
# Batch Loss: 255.2818871588679 Accuracy: tensor(0.9728, device='cuda:0')
# Batch Loss: 264.1611387311714 Accuracy: tensor(0.9726, device='cuda:0')
# Batch Loss: 272.4115960915806 Accuracy: tensor(0.9725, device='cuda:0')
# Batch Loss: 280.5871359886369 Accuracy: tensor(0.9725, device='cuda:0')
# Batch Loss: 289.85777910018805 Accuracy: tensor(0.9723, device='cuda:0')
# Batch Loss: 297.4935408408055 Accuracy: tensor(0.9724, device='cuda:0')
# Batch Loss: 305.56627757905517 Accuracy: tensor(0.9723, device='cuda:0')
# Batch Loss: 311.9586325058481 Accuracy: tensor(0.9725, device='cuda:0')
# Batch Loss: 318.92284401727375 Accuracy: tensor(0.9726, device='cuda:0')
# Batch Loss: 326.0746895916527 Accuracy: tensor(0.9726, device='cuda:0')
# Batch Loss: 333.1916970798047 Accuracy: tensor(0.9727, device='cuda:0')
# Batch Loss: 341.55730728420895 Accuracy: tensor(0.9726, device='cuda:0')
# Batch Loss: 351.1200967495097 Accuracy: tensor(0.9726, device='cuda:0')
#
# Train Loss: 356.2927765919594 Accuracy: tensor(0.9726, device='cuda:0')
# HBox(children=(FloatProgress(value=0.0, max=4569.0), HTML(value='')))
# Batch Loss: 5.95022791530937 Accuracy: tensor(0.9825, device='cuda:0')
# Batch Loss: 11.259089905535802 Accuracy: tensor(0.9819, device='cuda:0')
# Batch Loss: 17.651936556678265 Accuracy: tensor(0.9808, device='cuda:0')
# Batch Loss: 23.022261996986344 Accuracy: tensor(0.9805, device='cuda:0')
# Batch Loss: 29.157222141278908 Accuracy: tensor(0.9804, device='cuda:0')
# Batch Loss: 34.993587183533236 Accuracy: tensor(0.9802, device='cuda:0')
# Batch Loss: 40.82484887400642 Accuracy: tensor(0.9803, device='cuda:0')
# Batch Loss: 47.63644487131387 Accuracy: tensor(0.9801, device='cuda:0')
# Batch Loss: 54.44119714805856 Accuracy: tensor(0.9797, device='cuda:0')
# Batch Loss: 60.62732334132306 Accuracy: tensor(0.9794, device='cuda:0')
# Batch Loss: 66.8153197444044 Accuracy: tensor(0.9793, device='cuda:0')
# Batch Loss: 72.84241288388148 Accuracy: tensor(0.9794, device='cuda:0')
# Batch Loss: 78.5445801676251 Accuracy: tensor(0.9793, device='cuda:0')
# Batch Loss: 85.40871571120806 Accuracy: tensor(0.9792, device='cuda:0')
# Batch Loss: 92.00213050073944 Accuracy: tensor(0.9791, device='cuda:0')
# Batch Loss: 98.0448053847067 Accuracy: tensor(0.9792, device='cuda:0')
# Batch Loss: 103.23409695061855 Accuracy: tensor(0.9794, device='cuda:0')
# Batch Loss: 111.23790311836638 Accuracy: tensor(0.9791, device='cuda:0')
# Batch Loss: 116.76052583288401 Accuracy: tensor(0.9792, device='cuda:0')
# Batch Loss: 122.06689209258184 Accuracy: tensor(0.9792, device='cuda:0')
# Batch Loss: 129.4414491255302 Accuracy: tensor(0.9789, device='cuda:0')
# Batch Loss: 135.88993065361865 Accuracy: tensor(0.9789, device='cuda:0')
# Batch Loss: 142.1883678017184 Accuracy: tensor(0.9788, device='cuda:0')
# Batch Loss: 147.93254561326467 Accuracy: tensor(0.9790, device='cuda:0')
# Batch Loss: 153.7687511544209 Accuracy: tensor(0.9790, device='cuda:0')
# Batch Loss: 159.8905403285753 Accuracy: tensor(0.9790, device='cuda:0')
# Batch Loss: 167.6259540123865 Accuracy: tensor(0.9787, device='cuda:0')
# Batch Loss: 174.70381585042924 Accuracy: tensor(0.9786, device='cuda:0')
# Batch Loss: 180.77296052174643 Accuracy: tensor(0.9786, device='cuda:0')
# Batch Loss: 186.77975260582753 Accuracy: tensor(0.9786, device='cuda:0')
# Batch Loss: 192.56270631030202 Accuracy: tensor(0.9787, device='cuda:0')
# Batch Loss: 198.25371002708562 Accuracy: tensor(0.9788, device='cuda:0')
# Batch Loss: 204.7214415820781 Accuracy: tensor(0.9787, device='cuda:0')
# Batch Loss: 210.87742295931093 Accuracy: tensor(0.9788, device='cuda:0')
# Batch Loss: 217.62103367596865 Accuracy: tensor(0.9788, device='cuda:0')
# Batch Loss: 224.7293535755016 Accuracy: tensor(0.9787, device='cuda:0')
# Batch Loss: 232.30120168346912 Accuracy: tensor(0.9786, device='cuda:0')
# Batch Loss: 238.65264220372774 Accuracy: tensor(0.9787, device='cuda:0')
# Batch Loss: 245.78011949569918 Accuracy: tensor(0.9786, device='cuda:0')
# Batch Loss: 252.8711624436546 Accuracy: tensor(0.9785, device='cuda:0')
# Batch Loss: 258.9799887884874 Accuracy: tensor(0.9786, device='cuda:0')
# Batch Loss: 266.322475412162 Accuracy: tensor(0.9785, device='cuda:0')
# Batch Loss: 273.23114764294587 Accuracy: tensor(0.9784, device='cuda:0')
# Batch Loss: 279.7396065897774 Accuracy: tensor(0.9784, device='cuda:0')
# Batch Loss: 286.11982984258793 Accuracy: tensor(0.9784, device='cuda:0')
#
# Train Loss: 290.4047498011496 Accuracy: tensor(0.9784, device='cuda:0')
# HBox(children=(FloatProgress(value=0.0, max=4569.0), HTML(value='')))
# Batch Loss: 4.747336042812094 Accuracy: tensor(0.9844, device='cuda:0')
# Batch Loss: 8.954703130526468 Accuracy: tensor(0.9841, device='cuda:0')
# Batch Loss: 13.899251530412585 Accuracy: tensor(0.9841, device='cuda:0')
# Batch Loss: 18.000345575623214 Accuracy: tensor(0.9852, device='cuda:0')
# Batch Loss: 22.420883146231063 Accuracy: tensor(0.9847, device='cuda:0')
# Batch Loss: 27.804513107636012 Accuracy: tensor(0.9844, device='cuda:0')
# Batch Loss: 32.83899915718939 Accuracy: tensor(0.9842, device='cuda:0')
# Batch Loss: 37.70065838901792 Accuracy: tensor(0.9836, device='cuda:0')
# Batch Loss: 41.98828093428165 Accuracy: tensor(0.9836, device='cuda:0')
# Batch Loss: 47.556543557439 Accuracy: tensor(0.9833, device='cuda:0')
# Batch Loss: 53.11691668792628 Accuracy: tensor(0.9832, device='cuda:0')
# Batch Loss: 59.441648573381826 Accuracy: tensor(0.9828, device='cuda:0')
# Batch Loss: 64.58332884660922 Accuracy: tensor(0.9828, device='cuda:0')
# Batch Loss: 70.04744013980962 Accuracy: tensor(0.9826, device='cuda:0')
# Batch Loss: 75.54617273504846 Accuracy: tensor(0.9827, device='cuda:0')
# Batch Loss: 79.18660372623708 Accuracy: tensor(0.9829, device='cuda:0')
# Batch Loss: 85.16227089392487 Accuracy: tensor(0.9827, device='cuda:0')
# Batch Loss: 90.51017045474146 Accuracy: tensor(0.9826, device='cuda:0')
# Batch Loss: 96.15762134431861 Accuracy: tensor(0.9825, device='cuda:0')
# Batch Loss: 99.81825334427413 Accuracy: tensor(0.9828, device='cuda:0')
# Batch Loss: 104.29475110501517 Accuracy: tensor(0.9829, device='cuda:0')
# Batch Loss: 110.71698195987847 Accuracy: tensor(0.9826, device='cuda:0')
# Batch Loss: 115.5560325239785 Accuracy: tensor(0.9829, device='cuda:0')
# Batch Loss: 120.98148064897396 Accuracy: tensor(0.9829, device='cuda:0')
# Batch Loss: 126.01413308829069 Accuracy: tensor(0.9829, device='cuda:0')
# Batch Loss: 130.93497026595287 Accuracy: tensor(0.9829, device='cuda:0')
# Batch Loss: 136.24188380222768 Accuracy: tensor(0.9829, device='cuda:0')
# Batch Loss: 140.9437687031459 Accuracy: tensor(0.9829, device='cuda:0')
# Batch Loss: 146.04600769549143 Accuracy: tensor(0.9828, device='cuda:0')
# Batch Loss: 150.61614464141894 Accuracy: tensor(0.9828, device='cuda:0')
# Batch Loss: 157.03205214824993 Accuracy: tensor(0.9827, device='cuda:0')
# Batch Loss: 162.86742481205147 Accuracy: tensor(0.9826, device='cuda:0')
# Batch Loss: 169.2123060548911 Accuracy: tensor(0.9825, device='cuda:0')
# Batch Loss: 174.44526835286524 Accuracy: tensor(0.9824, device='cuda:0')
# Batch Loss: 181.02719160041306 Accuracy: tensor(0.9824, device='cuda:0')
# Batch Loss: 187.3064137691399 Accuracy: tensor(0.9823, device='cuda:0')
# Batch Loss: 193.39500300353393 Accuracy: tensor(0.9821, device='cuda:0')
# Batch Loss: 198.47103228233755 Accuracy: tensor(0.9821, device='cuda:0')
# Batch Loss: 203.28317539650016 Accuracy: tensor(0.9822, device='cuda:0')
# Batch Loss: 209.00890260958113 Accuracy: tensor(0.9822, device='cuda:0')
# Batch Loss: 214.26778249628842 Accuracy: tensor(0.9822, device='cuda:0')
# Batch Loss: 219.3867410221137 Accuracy: tensor(0.9822, device='cuda:0')
# Batch Loss: 223.52911278093234 Accuracy: tensor(0.9823, device='cuda:0')
# Batch Loss: 228.48516469297465 Accuracy: tensor(0.9823, device='cuda:0')
# Batch Loss: 233.43169989727903 Accuracy: tensor(0.9823, device='cuda:0')
#
# Train Loss: 237.73018968000542 Accuracy: tensor(0.9822, device='cuda:0')
# HBox(children=(FloatProgress(value=0.0, max=4569.0), HTML(value='')))
# Batch Loss: 3.5806213720934466 Accuracy: tensor(0.9881, device='cuda:0')
# Batch Loss: 7.790229026926681 Accuracy: tensor(0.9867, device='cuda:0')
# Batch Loss: 12.477759065572172 Accuracy: tensor(0.9867, device='cuda:0')
# Batch Loss: 15.528138181194663 Accuracy: tensor(0.9874, device='cuda:0')
# Batch Loss: 19.851275579072535 Accuracy: tensor(0.9874, device='cuda:0')
# Batch Loss: 24.287386760814115 Accuracy: tensor(0.9872, device='cuda:0')
# Batch Loss: 28.993453123723157 Accuracy: tensor(0.9868, device='cuda:0')
# Batch Loss: 32.88055994280148 Accuracy: tensor(0.9868, device='cuda:0')
# Batch Loss: 37.24389386770781 Accuracy: tensor(0.9861, device='cuda:0')
# Batch Loss: 41.06163769640261 Accuracy: tensor(0.9862, device='cuda:0')
# Batch Loss: 45.033046653319616 Accuracy: tensor(0.9863, device='cuda:0')
# Batch Loss: 47.81300180841936 Accuracy: tensor(0.9867, device='cuda:0')
# Batch Loss: 53.845785102050286 Accuracy: tensor(0.9865, device='cuda:0')
# Batch Loss: 58.004702377773356 Accuracy: tensor(0.9864, device='cuda:0')
# Batch Loss: 63.1404832341359 Accuracy: tensor(0.9862, device='cuda:0')
# Batch Loss: 68.86263743188465 Accuracy: tensor(0.9860, device='cuda:0')
# Batch Loss: 73.6544615738676 Accuracy: tensor(0.9857, device='cuda:0')
# Batch Loss: 77.82823348190868 Accuracy: tensor(0.9857, device='cuda:0')
# Batch Loss: 82.2872886582627 Accuracy: tensor(0.9857, device='cuda:0')
# Batch Loss: 86.62276696338085 Accuracy: tensor(0.9857, device='cuda:0')
# Batch Loss: 91.48931840102887 Accuracy: tensor(0.9857, device='cuda:0')
# Batch Loss: 94.81086917390348 Accuracy: tensor(0.9859, device='cuda:0')
# Batch Loss: 98.94467320502736 Accuracy: tensor(0.9859, device='cuda:0')
# Batch Loss: 103.13119065354113 Accuracy: tensor(0.9858, device='cuda:0')
# Batch Loss: 107.86295141722076 Accuracy: tensor(0.9856, device='cuda:0')
# Batch Loss: 111.62420744285919 Accuracy: tensor(0.9857, device='cuda:0')
# Batch Loss: 116.04100108414423 Accuracy: tensor(0.9857, device='cuda:0')
# Batch Loss: 120.63340932212304 Accuracy: tensor(0.9856, device='cuda:0')
# Batch Loss: 125.14654364110902 Accuracy: tensor(0.9856, device='cuda:0')
# Batch Loss: 128.52278550504707 Accuracy: tensor(0.9856, device='cuda:0')
# Batch Loss: 133.45712023065425 Accuracy: tensor(0.9855, device='cuda:0')
# Batch Loss: 137.29161718627438 Accuracy: tensor(0.9856, device='cuda:0')
# Batch Loss: 143.51625181990676 Accuracy: tensor(0.9855, device='cuda:0')
# Batch Loss: 148.23341939598322 Accuracy: tensor(0.9855, device='cuda:0')
# Batch Loss: 152.62911182176322 Accuracy: tensor(0.9854, device='cuda:0')
# Batch Loss: 158.19729711976834 Accuracy: tensor(0.9854, device='cuda:0')
# Batch Loss: 163.16163377370685 Accuracy: tensor(0.9854, device='cuda:0')
# Batch Loss: 167.71616514073685 Accuracy: tensor(0.9854, device='cuda:0')
# Batch Loss: 172.6945724178804 Accuracy: tensor(0.9853, device='cuda:0')
# Batch Loss: 177.36985981918406 Accuracy: tensor(0.9853, device='cuda:0')
# Batch Loss: 181.74540989508387 Accuracy: tensor(0.9853, device='cuda:0')
# Batch Loss: 187.39088579139207 Accuracy: tensor(0.9852, device='cuda:0')
# Batch Loss: 192.22969848185312 Accuracy: tensor(0.9851, device='cuda:0')
# Batch Loss: 196.52853012993 Accuracy: tensor(0.9851, device='cuda:0')
# Batch Loss: 200.5928440815769 Accuracy: tensor(0.9852, device='cuda:0')
#
# Train Loss: 203.39658461487852 Accuracy: tensor(0.9852, device='cuda:0')
# HBox(children=(FloatProgress(value=0.0, max=4569.0), HTML(value='')))
# Batch Loss: 2.796988053014502 Accuracy: tensor(0.9897, device='cuda:0')
# Batch Loss: 5.51443381421268 Accuracy: tensor(0.9909, device='cuda:0')
# Batch Loss: 8.431930903461762 Accuracy: tensor(0.9904, device='cuda:0')
# Batch Loss: 12.87028517969884 Accuracy: tensor(0.9891, device='cuda:0')
# Batch Loss: 15.87795611016918 Accuracy: tensor(0.9893, device='cuda:0')
# Batch Loss: 18.97159853519406 Accuracy: tensor(0.9890, device='cuda:0')
# Batch Loss: 22.569773504976183 Accuracy: tensor(0.9885, device='cuda:0')
# Batch Loss: 25.15683845593594 Accuracy: tensor(0.9888, device='cuda:0')
# Batch Loss: 28.716064281528816 Accuracy: tensor(0.9888, device='cuda:0')
# Batch Loss: 31.962540700740647 Accuracy: tensor(0.9885, device='cuda:0')
# Batch Loss: 35.821676593099255 Accuracy: tensor(0.9885, device='cuda:0')
# Batch Loss: 39.200067481200676 Accuracy: tensor(0.9885, device='cuda:0')
# Batch Loss: 43.6157150111394 Accuracy: tensor(0.9881, device='cuda:0')
# Batch Loss: 46.21663416334195 Accuracy: tensor(0.9883, device='cuda:0')
# Batch Loss: 48.98863719793735 Accuracy: tensor(0.9885, device='cuda:0')
# Batch Loss: 53.09092372935265 Accuracy: tensor(0.9883, device='cuda:0')
# Batch Loss: 56.455837306624744 Accuracy: tensor(0.9884, device='cuda:0')
# Batch Loss: 60.173785777704325 Accuracy: tensor(0.9883, device='cuda:0')
# Batch Loss: 63.712613930983935 Accuracy: tensor(0.9883, device='cuda:0')
# Batch Loss: 67.90878868027357 Accuracy: tensor(0.9882, device='cuda:0')
# Batch Loss: 73.01102967065526 Accuracy: tensor(0.9880, device='cuda:0')
# Batch Loss: 77.1365115895751 Accuracy: tensor(0.9879, device='cuda:0')
# Batch Loss: 81.11640828434611 Accuracy: tensor(0.9878, device='cuda:0')
# Batch Loss: 84.38842130010016 Accuracy: tensor(0.9878, device='cuda:0')
# Batch Loss: 88.37260069756303 Accuracy: tensor(0.9878, device='cuda:0')
# Batch Loss: 93.08798937441316 Accuracy: tensor(0.9876, device='cuda:0')
# Batch Loss: 98.04107048385777 Accuracy: tensor(0.9875, device='cuda:0')
# Batch Loss: 102.30837650957983 Accuracy: tensor(0.9874, device='cuda:0')
# Batch Loss: 106.52412678580731 Accuracy: tensor(0.9873, device='cuda:0')
# Batch Loss: 109.92701967433095 Accuracy: tensor(0.9874, device='cuda:0')
# Batch Loss: 112.88486894581001 Accuracy: tensor(0.9875, device='cuda:0')
# Batch Loss: 116.11397787369788 Accuracy: tensor(0.9875, device='cuda:0')
# Batch Loss: 119.48578288179124 Accuracy: tensor(0.9875, device='cuda:0')
# Batch Loss: 124.02382465341361 Accuracy: tensor(0.9874, device='cuda:0')
# Batch Loss: 127.63539373734966 Accuracy: tensor(0.9873, device='cuda:0')
# Batch Loss: 131.62619350629393 Accuracy: tensor(0.9873, device='cuda:0')
# Batch Loss: 134.6887611899292 Accuracy: tensor(0.9874, device='cuda:0')
# Batch Loss: 139.57107011822518 Accuracy: tensor(0.9873, device='cuda:0')
# Batch Loss: 143.24574435845716 Accuracy: tensor(0.9873, device='cuda:0')
# Batch Loss: 147.93325539521175 Accuracy: tensor(0.9872, device='cuda:0')
# Batch Loss: 152.57177031080937 Accuracy: tensor(0.9872, device='cuda:0')
# Batch Loss: 156.38686177047202 Accuracy: tensor(0.9871, device='cuda:0')
# Batch Loss: 160.92507232906064 Accuracy: tensor(0.9871, device='cuda:0')
# Batch Loss: 166.37202595215058 Accuracy: tensor(0.9870, device='cuda:0')
# Batch Loss: 169.69203439709963 Accuracy: tensor(0.9871, device='cuda:0')
#
# Train Loss: 173.27425621956354 Accuracy: tensor(0.9870, device='cuda:0')

# %%
losses, accuracies
# Out:
# ([1322.8536492418498,
#   978.0860839579254,
#   780.4395019989461,
#   597.8655356639065,
#   461.94001254672185,
#   356.2927765919594,
#   290.4047498011496,
#   237.73018968000542,
#   203.39658461487852,
#   173.27425621956354],
#  [tensor(0.8772, device='cuda:0'),
#   tensor(0.9136, device='cuda:0'),
#   tensor(0.9335, device='cuda:0'),
#   tensor(0.9511, device='cuda:0'),
#   tensor(0.9633, device='cuda:0'),
#   tensor(0.9726, device='cuda:0'),
#   tensor(0.9784, device='cuda:0'),
#   tensor(0.9822, device='cuda:0'),
#   tensor(0.9852, device='cuda:0'),
#   tensor(0.9870, device='cuda:0')])

# %% [markdown]
#  # Learn & Test Model
#  ## Test Model

# %%
model.eval()

test_correct = 0
test_total = 0

for input_ids_batch, attention_masks_batch, y_batch in tqdm(test_loader):
    y_batch = y_batch.to(device)
    y_pred = model(input_ids_batch.to(device), attention_mask=attention_masks_batch.to(device))[0]
    _, predicted = torch.max(y_pred, 1)
    test_correct += (predicted == y_batch).sum()
    test_total += len(y_batch)

print("Accuracy:", test_correct.float() / test_total)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=3073.0), HTML(value='')))
# /usr/local/lib/python3.6/dist-packages/transformers/tokenization_utils_base.py:2179: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   FutureWarning,
# Accuracy: tensor(0.9049, device='cuda:0')

# %%
# 모델 저장하기
torch.save(model.state_dict(), "/content/drive/MyDrive/Colab Notebooks/Korea Univ/001. NLP Project/NSMC_Kor/12231344.pt")

# %% [markdown]
# # Prediction (W ko_data.csv)

# %%
class NSMCDataset_ko(Dataset):
  
  def __init__(self, csv_file):
    # 일부 값중에 NaN이 있음...
    self.dataset = pd.read_csv(csv_file, sep=',', encoding='CP949').dropna(axis=0) 
    # 중복제거
    #self.dataset.drop_duplicates(subset=['document'], inplace=True)
    self.tokenizer = AutoTokenizer.from_pretrained("monologg/koelectra-base-v3-discriminator")

    print(self.dataset.describe())
  
  def __len__(self):
    return len(self.dataset)

  def __getitem__(self, idx):
    row = self.dataset.iloc[idx, 1:3].values
    text = row[0]
    
    

    # ko_data label 없음
    #y = row[1]

    inputs = self.tokenizer(
        text, 
        return_tensors='pt',
        truncation=True,
        max_length=40,
        pad_to_max_length=True,
        add_special_tokens=True
        )
    

    input_ids = inputs['input_ids'][0]
    attention_mask = inputs['attention_mask'][0]

    return input_ids, attention_mask

# %%
test_dataset = NSMCDataset_ko("/content/drive/MyDrive/Colab Notebooks/Korea Univ/001. NLP Project/NSMC_Kor/ko_data.csv")
# Out:
#                  Id
# count  11187.000000
# mean    5593.000000
# std     3229.553065
# min        0.000000
# 25%     2796.500000
# 50%     5593.000000
# 75%     8389.500000
# max    11186.000000

# %%
# 입력데이터 1개씩 predicted 값 생성을 위해 batch_size 1 로 설정

test_loader = DataLoader(test_dataset, batch_size=1, shuffle=False)

# %%
model.eval()

test_preds = []

for input_ids_batch, attention_masks_batch in tqdm(test_loader):

  y_pred = model(input_ids_batch.to(device), attention_mask=attention_masks_batch.to(device))[0]
  _, predicted = torch.max(y_pred, 1)


  preds = y_pred.detach()
  test_preds.append(preds.cpu().numpy())
# Out:
# HBox(children=(FloatProgress(value=0.0, max=11187.0), HTML(value='')))
# /usr/local/lib/python3.6/dist-packages/transformers/tokenization_utils_base.py:2179: FutureWarning: The `pad_to_max_length` argument is deprecated and will be removed in a future version, use `padding=True` or `padding='longest'` to pad to the longest sequence in the batch, or use `padding='max_length'` to pad to a max length. In this case, you can give a specific length with `max_length` (e.g. `max_length=45`) or leave max_length to None to pad to the maximal input size of the model (e.g. 512 for Bert).
#   FutureWarning,

# %%
import numpy as np

outputs = []
for _ in test_preds:
    # argmax를 사용해서 가장 높은 확률로 예측한 class 반환
    predicted_class_indices=np.argmax(_, axis=1).tolist()
    outputs.append(predicted_class_indices)

result = np.concatenate(outputs)

# %%
len(result)
# Out:
# 11187

# %%
ko_data = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/Korea Univ/001. NLP Project/NSMC_Kor/ko_data.csv', delimiter=',', encoding='CP949')

# %%
outfile_df = pd.DataFrame()

outfile_df['Id'] = ko_data['Id']
outfile_df['Predicted'] = result

# %%
outfile_df.to_csv("/content/drive/MyDrive/Colab Notebooks/Korea Univ/001. NLP Project/NSMC_Kor/12231344.csv", index=False)
